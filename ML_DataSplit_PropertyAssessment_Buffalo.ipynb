# %% [markdown]
# <a href="https://colab.research.google.com/github/KatBCN/ML-PropertyAssessment/blob/main/ML_DataSplit_PropertyAssessment_Buffalo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Splitting into Train / Validation / Test
#
# In this notebook, we will follow the code example show in Lab 4 in order to partition the data prior to developing our pre-process and training pipeline.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', None)  #set display to show all columns

# %% [markdown]
# We import the data from our [GitHub repository](https://github.com/KatBCN/ML-PropertyAssessment).

# %%
data_link = "https://raw.githubusercontent.com/KatBCN/ML-PropertyAssessment/main/Data/2019-2020_Assessment_Roll.csv"
df = pd.read_csv(data_link)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Show number of rows and columns in dataframe
df.shape
# Out:
# (93862, 51)

# %%
# Show column names
df.columns
# Out:
# Index(['SBL', 'Tax District', 'Print Key', 'Front', 'Depth', 'Property Class',
#        'Property Class Description', 'Previous Property Class', 'Owner1',
#        'Owner2', 'Previous Owner', 'Mail1', 'Mail2', 'Mail3', 'Mail4',
#        'House Number', 'Street', 'Address', 'City', 'State', 'Zipcode',
#        'Zipcode Extension', 'Deed Book', 'Deed Page', 'Deed Date', 'Roll',
#        'Land Value', 'Total Value', 'Sale Price', 'Year Built',
#        'First Story Area', 'Second Story Area', 'Total Living Area',
#        'Overall Condition', 'Building Style', 'Heat Type', 'Basement Type',
#        '# of Stories', '# of Fireplaces', '# of Beds', '# of Baths',
#        '# of Kitchens', 'Council District', 'Police District', 'Census Tract',
#        'Census Block Group', 'Census Block', 'Neighborhood', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
df.head()
# Out:
#                  SBL  Tax District          Print Key   Front    Depth  \
# 0  1113100012001122A      147003.0  111.31-12-1.122/A    0.00     0.00
# 1   1011500001001111      147012.0     101.15-1-1.111    0.00     0.00
# 2   0785000008001000      147009.0          78.50-8-1   65.00    82.57
# 3   1007300008009111      147003.0     100.73-8-9.111   50.00   200.00
# 4   1321500002004000      147013.0         132.15-2-4  521.34  1184.60
#
#    Property Class Property Class Description  Previous Property Class  \
# 0             873           GAS MEAS STATION                    873.0
# 1             330     COMMERCIAL VACANT LAND                    330.0
# 2             311    RESIDENTIAL VACANT LAND                      NaN
# 3             311    RESIDENTIAL VACANT LAND                    311.0
# 4             340     INDUSTRIAL VACANT LAND                    340.0
#
#                            Owner1 Owner2  Previous Owner Mail1 Mail2  \
# 0          NATIONAL FUEL GAS DIST   CORP             NaN   NaN   NaN
# 1  AROUND THE CLOCK CAR WASH,INC.    NaN             NaN   NaN   NaN
# 2   THE MARRANO/MARC-EQUITY CORP.    NaN             NaN   NaN   NaN
# 3              MARIAH LORETTA LLC    NaN             NaN   NaN   NaN
# 4  BUFFALO URBAN DEVELOPMENT CORP    NaN             NaN   NaN   NaN
#
#                   Mail3              Mail4  House Number          Street  \
# 0          6363 MAIN ST  WILLIAMSVILLE, NY         725.0      WASHINGTON
# 1         6547 EMILY LN       LOCKPORT, NY         119.0             WEX
# 2       2730 TRANSIT RD    WEST SENECA, NY         142.0  RACHEL VINCENT
# 3  100 S WOODLAND RIDGE           ELMA, NY         289.0          LOCUST
# 4            275 OAK ST        BUFFALO, NY         126.0    LABORERS WAY
#
#   Address     City State  Zipcode  Zipcode Extension Deed Book Deed Page  \
# 0     NaN  BUFFALO    NY  14203.0                NaN       NaN       NaN
# 1     NaN  BUFFALO    NY  14211.0                NaN     11144    9356.0
# 2     NaN  BUFFALO    NY  14216.0                NaN     11331    1637.0
# 3     NaN  BUFFALO    NY  14204.0                NaN     11309     505.0
# 4     NaN  BUFFALO    NY  14203.0                NaN     11125    6721.0
#
#     Deed Date  Roll  Land Value  Total Value  Sale Price  Year Built  \
# 0  09/09/9999     6           0        13006           0         NaN
# 1  09/09/9999     1        2900         2900           0         NaN
# 2  09/09/9999     1        1700         1700           0         NaN
# 3  09/09/9999     1        3800         3800           0         NaN
# 4  09/09/9999     8      337000       337000           0         NaN
#
#    First Story Area  Second Story Area  Total Living Area  Overall Condition  \
# 0               NaN                NaN                  0                NaN
# 1               NaN                NaN                  0                NaN
# 2               NaN                NaN                  0                NaN
# 3               NaN                NaN                  0                NaN
# 4               NaN                NaN                  0                NaN
#
#    Building Style  Heat Type  Basement Type  # of Stories  # of Fireplaces  \
# 0             NaN        NaN            NaN           NaN                0
# 1             NaN        NaN            NaN           NaN                0
# 2             NaN        NaN            NaN           NaN                0
# 3             NaN        NaN            NaN           NaN                0
# 4             NaN        NaN            NaN           NaN                0
#
#    # of Beds  # of Baths  # of Kitchens Council District Police District  \
# 0          0         0.0            NaN              NaN             NaN
# 1          0         0.0            NaN              NaN             NaN
# 2          0         0.0            NaN              NaN             NaN
# 3          0         0.0            NaN              NaN             NaN
# 4          0         0.0            NaN              NaN             NaN
#
#   Census Tract Census Block Group Census Block Neighborhood  Latitude  \
# 0          NaN                NaN          NaN          NaN       NaN
# 1          NaN                NaN          NaN          NaN       NaN
# 2          NaN                NaN          NaN          NaN       NaN
# 3          NaN                NaN          NaN          NaN       NaN
# 4          NaN                NaN          NaN          NaN       NaN
#
#    Longitude Location
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN

# %% [markdown]
# Documentation: [pandas.DataFrame.set_index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html)

# %%
# Set index as column SBL
df.set_index('SBL', drop=True, append=False, inplace=True, verify_integrity=True)

# %%
df.head()
# Out:
#                    Tax District          Print Key   Front    Depth  \
# SBL
# 1113100012001122A      147003.0  111.31-12-1.122/A    0.00     0.00
# 1011500001001111       147012.0     101.15-1-1.111    0.00     0.00
# 0785000008001000       147009.0          78.50-8-1   65.00    82.57
# 1007300008009111       147003.0     100.73-8-9.111   50.00   200.00
# 1321500002004000       147013.0         132.15-2-4  521.34  1184.60
#
#                    Property Class Property Class Description  \
# SBL
# 1113100012001122A             873           GAS MEAS STATION
# 1011500001001111              330     COMMERCIAL VACANT LAND
# 0785000008001000              311    RESIDENTIAL VACANT LAND
# 1007300008009111              311    RESIDENTIAL VACANT LAND
# 1321500002004000              340     INDUSTRIAL VACANT LAND
#
#                    Previous Property Class                          Owner1  \
# SBL
# 1113100012001122A                    873.0          NATIONAL FUEL GAS DIST
# 1011500001001111                     330.0  AROUND THE CLOCK CAR WASH,INC.
# 0785000008001000                       NaN   THE MARRANO/MARC-EQUITY CORP.
# 1007300008009111                     311.0              MARIAH LORETTA LLC
# 1321500002004000                     340.0  BUFFALO URBAN DEVELOPMENT CORP
#
#                   Owner2  Previous Owner Mail1 Mail2                 Mail3  \
# SBL
# 1113100012001122A   CORP             NaN   NaN   NaN          6363 MAIN ST
# 1011500001001111     NaN             NaN   NaN   NaN         6547 EMILY LN
# 0785000008001000     NaN             NaN   NaN   NaN       2730 TRANSIT RD
# 1007300008009111     NaN             NaN   NaN   NaN  100 S WOODLAND RIDGE
# 1321500002004000     NaN             NaN   NaN   NaN            275 OAK ST
#
#                                Mail4  House Number          Street Address  \
# SBL
# 1113100012001122A  WILLIAMSVILLE, NY         725.0      WASHINGTON     NaN
# 1011500001001111        LOCKPORT, NY         119.0             WEX     NaN
# 0785000008001000     WEST SENECA, NY         142.0  RACHEL VINCENT     NaN
# 1007300008009111            ELMA, NY         289.0          LOCUST     NaN
# 1321500002004000         BUFFALO, NY         126.0    LABORERS WAY     NaN
#
#                       City State  Zipcode  Zipcode Extension Deed Book  \
# SBL
# 1113100012001122A  BUFFALO    NY  14203.0                NaN       NaN
# 1011500001001111   BUFFALO    NY  14211.0                NaN     11144
# 0785000008001000   BUFFALO    NY  14216.0                NaN     11331
# 1007300008009111   BUFFALO    NY  14204.0                NaN     11309
# 1321500002004000   BUFFALO    NY  14203.0                NaN     11125
#
#                   Deed Page   Deed Date  Roll  Land Value  Total Value  \
# SBL
# 1113100012001122A       NaN  09/09/9999     6           0        13006
# 1011500001001111     9356.0  09/09/9999     1        2900         2900
# 0785000008001000     1637.0  09/09/9999     1        1700         1700
# 1007300008009111      505.0  09/09/9999     1        3800         3800
# 1321500002004000     6721.0  09/09/9999     8      337000       337000
#
#                    Sale Price  Year Built  First Story Area  \
# SBL
# 1113100012001122A           0         NaN               NaN
# 1011500001001111            0         NaN               NaN
# 0785000008001000            0         NaN               NaN
# 1007300008009111            0         NaN               NaN
# 1321500002004000            0         NaN               NaN
#
#                    Second Story Area  Total Living Area  Overall Condition  \
# SBL
# 1113100012001122A                NaN                  0                NaN
# 1011500001001111                 NaN                  0                NaN
# 0785000008001000                 NaN                  0                NaN
# 1007300008009111                 NaN                  0                NaN
# 1321500002004000                 NaN                  0                NaN
#
#                    Building Style  Heat Type  Basement Type  # of Stories  \
# SBL
# 1113100012001122A             NaN        NaN            NaN           NaN
# 1011500001001111              NaN        NaN            NaN           NaN
# 0785000008001000              NaN        NaN            NaN           NaN
# 1007300008009111              NaN        NaN            NaN           NaN
# 1321500002004000              NaN        NaN            NaN           NaN
#
#                    # of Fireplaces  # of Beds  # of Baths  # of Kitchens  \
# SBL
# 1113100012001122A                0          0         0.0            NaN
# 1011500001001111                 0          0         0.0            NaN
# 0785000008001000                 0          0         0.0            NaN
# 1007300008009111                 0          0         0.0            NaN
# 1321500002004000                 0          0         0.0            NaN
#
#                   Council District Police District Census Tract  \
# SBL
# 1113100012001122A              NaN             NaN          NaN
# 1011500001001111               NaN             NaN          NaN
# 0785000008001000               NaN             NaN          NaN
# 1007300008009111               NaN             NaN          NaN
# 1321500002004000               NaN             NaN          NaN
#
#                   Census Block Group Census Block Neighborhood  Latitude  \
# SBL
# 1113100012001122A                NaN          NaN          NaN       NaN
# 1011500001001111                 NaN          NaN          NaN       NaN
# 0785000008001000                 NaN          NaN          NaN       NaN
# 1007300008009111                 NaN          NaN          NaN       NaN
# 1321500002004000                 NaN          NaN          NaN       NaN
#
#                    Longitude Location
# SBL
# 1113100012001122A        NaN      NaN
# 1011500001001111         NaN      NaN
# 0785000008001000         NaN      NaN
# 1007300008009111         NaN      NaN
# 1321500002004000         NaN      NaN

# %% [markdown]
# ### (1) split available data into training + test set
#
# notice that we call `learn` the training partition to avoid clash with train later on on train/val split
#
# Documentation: [sklearn.model_selection.train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)

# %%
learn, test = train_test_split(df, test_size=0.25, random_state=22, shuffle=True, stratify=None)

# %%
learn.shape
# Out:
# (70396, 50)

# %%
test.shape
# Out:
# (23466, 50)

# %% [markdown]
# ### (2) use train/val split as resampling method

# %%
# split "learn" into train + validation
train, val = train_test_split(learn, test_size=0.25, random_state=22, shuffle=True, stratify=None)

# %%
train.shape
# Out:
# (52797, 50)

# %%
val.shape
# Out:
# (17599, 50)

# %% [markdown]
# We use pickle filetype to save datatypes and indices

# %%
train.to_pickle("train_BuffaloProperty.pkl")

# %%
val.to_pickle("validation_BuffaloProperty.pkl")

# %%
test.to_pickle("test_BuffaloProperty.pkl")

# %%
df_val = pd.read_pickle("validation_BuffaloProperty.pkl")

# %%
df_val.head()
# Out:
#                      Tax District         Print Key  Front  Depth  \
# SBL
# 1334600001006000         147013.0        133.46-1-6   50.0  155.0
# 1007600006028000         147004.0       100.76-6-28   30.0  127.0
# 1337900001046000         147014.0       133.79-1-46   32.0  183.0
# 1106000001002200606      147001.0  110.60-1-2.2/606    5.0  239.0
# 1004400001004000         147005.0        100.44-1-4   29.0  106.0
#
#                      Property Class Property Class Description  \
# SBL
# 1334600001006000                210        ONE FAMILY DWELLING
# 1007600006028000                210        ONE FAMILY DWELLING
# 1337900001046000                210        ONE FAMILY DWELLING
# 1106000001002200606             210        ONE FAMILY DWELLING
# 1004400001004000                220        TWO FAMILY DWELLING
#
#                      Previous Property Class                    Owner1  \
# SBL
# 1334600001006000                       210.0       HRYNCZAK PETRO (LE)
# 1007600006028000                       210.0  WILLIAMSVILLE PROPERTIES
# 1337900001046000                       210.0          SPEIDEL EDWARD H
# 1106000001002200606                    210.0              BAUER LISA M
# 1004400001004000                       220.0            ROBINSON LINDA
#
#                                    Owner2  Previous Owner Mail1 Mail2  \
# SBL
# 1334600001006000     HRYNCZAK JULIA  (LE)             NaN   NaN   NaN
# 1007600006028000                      NaN             NaN   NaN   NaN
# 1337900001046000                      NaN             NaN   NaN   NaN
# 1106000001002200606                   NaN             NaN   NaN   NaN
# 1004400001004000                      NaN             NaN   NaN   NaN
#
#                                        Mail3        Mail4  House Number  \
# SBL
# 1334600001006000              27 CRYSTAL AVE  BUFFALO, NY          27.0
# 1007600006028000     3842 HARLEM RD #400-291  BUFFALO, NY         578.0
# 1337900001046000               62 ALDRICH PL  BUFFALO, NY          62.0
# 1106000001002200606        606 ADMIRALS WALK  BUFFALO, NY          75.0
# 1004400001004000                  162 KAY ST  BUFFALO, NY         581.0
#
#                          Street Address     City State  Zipcode  \
# SBL
# 1334600001006000        CRYSTAL     NaN  BUFFALO    NY  14220.0
# 1007600006028000         WILSON     NaN  BUFFALO    NY  14211.0
# 1337900001046000        ALDRICH     NaN  BUFFALO    NY  14220.0
# 1106000001002200606      OJIBWA     NaN  BUFFALO    NY  14202.0
# 1004400001004000     FERRY EAST     NaN  BUFFALO    NY  14211.0
#
#                      Zipcode Extension Deed Book Deed Page   Deed Date  Roll  \
# SBL
# 1334600001006000                   NaN     11109    1936.0  11/07/2005     1
# 1007600006028000                   NaN     11252      9228  09/12/2013     1
# 1337900001046000                   NaN     10915      2610  04/22/1997     1
# 1106000001002200606                NaN     10970    3370.0  08/17/2000     1
# 1004400001004000                   NaN     11225      2056  06/20/2012     1
#
#                      Land Value  Total Value  Sale Price  Year Built  \
# SBL
# 1334600001006000           7700        65000           1      1955.0
# 1007600006028000           1700        12000        3000      1817.0
# 1337900001046000           6400        67000       64000      1920.0
# 1106000001002200606       12400       150000      133500      1991.0
# 1004400001004000           1000        22100           1      1900.0
#
#                      First Story Area  Second Story Area  Total Living Area  \
# SBL
# 1334600001006000                  NaN                NaN               1066
# 1007600006028000                  NaN                NaN               1498
# 1337900001046000                  NaN                NaN               1616
# 1106000001002200606               NaN                NaN               1008
# 1004400001004000                  NaN                NaN               2120
#
#                      Overall Condition  Building Style  Heat Type  \
# SBL
# 1334600001006000                   3.0             1.0        2.0
# 1007600006028000                   2.0             8.0        2.0
# 1337900001046000                   3.0             8.0        2.0
# 1106000001002200606                3.0            14.0        2.0
# 1004400001004000                   3.0             8.0        3.0
#
#                      Basement Type  # of Stories  # of Fireplaces  # of Beds  \
# SBL
# 1334600001006000               4.0           NaN                0          3
# 1007600006028000               3.0           NaN                0          2
# 1337900001046000               4.0           NaN                0          4
# 1106000001002200606            1.0           NaN                0          2
# 1004400001004000               4.0           NaN                0          6
#
#                      # of Baths  # of Kitchens Council District  \
# SBL
# 1334600001006000            1.0            NaN            SOUTH
# 1007600006028000            1.0            NaN         FILLMORE
# 1337900001046000            1.1            NaN            SOUTH
# 1106000001002200606         2.0            NaN         FILLMORE
# 1004400001004000            2.0            NaN           MASTEN
#
#                     Police District Census Tract Census Block Group  \
# SBL
# 1334600001006000         District A            2                  3
# 1007600006028000         District C          166                  2
# 1337900001046000         District A            6                  4
# 1106000001002200606      District B        72.02                  1
# 1004400001004000         District C           35                  2
#
#                     Census Block       Neighborhood   Latitude  Longitude  \
# SBL
# 1334600001006000            3005      Hopkins-Tifft  42.845672 -78.831177
# 1007600006028000            2005  Broadway Fillmore  42.901118 -78.840372
# 1337900001046000            4006         South Park  42.833233 -78.821461
# 1106000001002200606         1006            Central  42.884581 -78.886420
# 1004400001004000            2005           MLK Park  42.914422 -78.842605
#
#                                                      Location
# SBL
# 1334600001006000      (42.84567227521914, -78.83117735751773)
# 1007600006028000      (42.90111849963285, -78.84037233811456)
# 1337900001046000     (42.833232834431946, -78.82146132555859)
# 1106000001002200606    (42.88458058533622, -78.8864199240598)
# 1004400001004000     (42.914422066855444, -78.84260536602814)
